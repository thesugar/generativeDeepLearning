# %%
import os
from utils.loaders import load_mnist
from models.AE import Autoencoder

# %%
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = f'run/{SECTION}/'
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

MODE = 'build' # 'load'

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %%
# Define the structure of the neural network
AE = Autoencoder(
    input_dim=(28, 28, 1)
    , encoder_conv_filters= [32, 64, 64, 64]  # これは shape ではなく、「4 層重ねること」（リストの長さ）と、各層のフィルターの枚数の指定を行っている
    , encoder_conv_kernel_size= [3, 3, 3, 3]  # こちらは各層の kernel_size を指定している
    , encoder_conv_strides= [1, 2, 2, 1]
    , decoder_conv_t_filters= [64, 64, 32, 1]
    , decoder_conv_t_kernel_size= [3, 3, 3, 3]
    , decoder_conv_t_strides= [1, 2, 2, 1]
    , z_dim=2
)

if MODE == 'build':
    AE.save(RUN_FOLDER)
else: # 'load'
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
AE.encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoer_input (InputLayer)    [(None, 28, 28, 1)]       0
# _________________________________________________________________
# encoder_conv_0 (Conv2D)      (None, 28, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 28, 28, 32)        0
# _________________________________________________________________
# encoder_conv_1 (Conv2D)      (None, 14, 14, 64)        18496
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# encoder_conv_2 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# encoder_conv_3 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 6274
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH = 0

# %%
AE.compile(LEARNING_RATE)

# %%
AE.train(
    x_train[:1000]
    , batch_size= BATCH_SIZE
    , epochs = 200
    , run_folder= RUN_FOLDER
    , initial_epoch= INITIAL_EPOCH
)
# Out:
# odel to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0382 - lr: 5.0000e-04
# Epoch 115/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0382
# Epoch 00115: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0382 - lr: 5.0000e-04
# Epoch 116/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0383
# Epoch 00116: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0382 - lr: 5.0000e-04
# Epoch 117/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 00117: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0380 - lr: 5.0000e-04
# Epoch 118/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 00118: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0383 - lr: 5.0000e-04
# Epoch 119/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0379
# Epoch 00119: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0379 - lr: 5.0000e-04
# Epoch 120/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0377
# Epoch 00120: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 121/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0380
# Epoch 00121: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0380 - lr: 5.0000e-04
# Epoch 122/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00122: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 123/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0377
# Epoch 00123: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 124/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0375
# Epoch 00124: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0376 - lr: 5.0000e-04
# Epoch 125/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0378
# Epoch 00125: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0378 - lr: 5.0000e-04
# Epoch 126/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0375
# Epoch 00126: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0375 - lr: 5.0000e-04
# Epoch 127/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0374
# Epoch 00127: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 128/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00128: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 129/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0378
# Epoch 00129: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0377 - lr: 5.0000e-04
# Epoch 130/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0374
# Epoch 00130: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 131/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00131: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0374 - lr: 5.0000e-04
# Epoch 132/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0375
# Epoch 00132: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0376 - lr: 5.0000e-04
# Epoch 133/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0380
# Epoch 00133: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0380 - lr: 5.0000e-04
# Epoch 134/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0374
# Epoch 00134: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0373 - lr: 5.0000e-04
# Epoch 135/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00135: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0373 - lr: 5.0000e-04
# Epoch 136/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0371
# Epoch 00136: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 137/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00137: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 23s 707ms/step - loss: 0.0373 - lr: 5.0000e-04
# Epoch 138/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0371
# Epoch 00138: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 2s 52ms/step - loss: 0.0371 - lr: 5.0000e-04
# Epoch 139/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00139: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0373 - lr: 5.0000e-04
# Epoch 140/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 00140: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 141/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00141: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 142/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 00142: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 143/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 00143: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 144/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 00144: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 145/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00145: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 146/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0371
# Epoch 00146: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0371 - lr: 5.0000e-04
# Epoch 147/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0371
# Epoch 00147: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0372 - lr: 5.0000e-04
# Epoch 148/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00148: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0369 - lr: 5.0000e-04
# Epoch 149/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 00149: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0367 - lr: 5.0000e-04
# Epoch 150/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00150: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0370 - lr: 5.0000e-04
# Epoch 151/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0367
# Epoch 00151: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0367 - lr: 5.0000e-04
# Epoch 152/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 00152: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 153/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 00153: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 154/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0368
# Epoch 00154: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0368 - lr: 5.0000e-04
# Epoch 155/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 00155: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 156/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0364
# Epoch 00156: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 157/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0365
# Epoch 00157: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 35ms/step - loss: 0.0365 - lr: 5.0000e-04
# Epoch 158/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0367
# Epoch 00158: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0367 - lr: 5.0000e-04
# Epoch 159/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0366
# Epoch 00159: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0366 - lr: 5.0000e-04
# Epoch 160/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0364
# Epoch 00160: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 161/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00161: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 162/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00162: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 163/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00163: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 164/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0364
# Epoch 00164: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0364 - lr: 5.0000e-04
# Epoch 165/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00165: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 166/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0362
# Epoch 00166: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 167/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0363
# Epoch 00167: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 168/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 00168: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 169/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0362
# Epoch 00169: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 170/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 00170: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0363 - lr: 5.0000e-04
# Epoch 171/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0360
# Epoch 00171: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 172/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0360
# Epoch 00172: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 173/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0357
# Epoch 00173: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 174/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 00174: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0362 - lr: 5.0000e-04
# Epoch 175/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00175: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0361 - lr: 5.0000e-04
# Epoch 176/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 00176: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 177/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0361
# Epoch 00177: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 178/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 00178: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 179/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 00179: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 180/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 00180: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 181/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 00181: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 182/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 00182: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 183/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0359
# Epoch 00183: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 184/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0357
# Epoch 00184: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 185/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 00185: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 186/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0357
# Epoch 00186: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 187/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0357
# Epoch 00187: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0358 - lr: 5.0000e-04
# Epoch 188/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0356
# Epoch 00188: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 189/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0359
# Epoch 00189: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 190/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0356
# Epoch 00190: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0356 - lr: 5.0000e-04
# Epoch 191/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 00191: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0360 - lr: 5.0000e-04
# Epoch 192/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00192: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 46ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 193/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0354
# Epoch 00193: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 44ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 194/200
# 30/32 [===========================>..] - ETA: 0s - loss: 0.0353
# Epoch 00194: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0354 - lr: 5.0000e-04
# Epoch 195/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0353
# Epoch 00195: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0353 - lr: 5.0000e-04
# Epoch 196/200
# 32/32 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 00196: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 197/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0357
# Epoch 00197: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0357 - lr: 5.0000e-04
# Epoch 198/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0355
# Epoch 00198: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 41ms/step - loss: 0.0355 - lr: 5.0000e-04
# Epoch 199/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0358
# Epoch 00199: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0359 - lr: 5.0000e-04
# Epoch 200/200
# 31/32 [============================>.] - ETA: 0s - loss: 0.0353
# Epoch 00200: saving model to run/vae0001_digits/weights/weights.h5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0353 - lr: 5.0000e-04
